# %% [markdown]
# ## Reverse Linked List

# %%
def reverseList(self, head):
    """
    Time: O(n)| Space: O(1)
    """
    prev = None
    cur = head

    while cur:
        next = cur.next
        cur.next = prev
        prev = cur
        cur = next
    
    return prev
